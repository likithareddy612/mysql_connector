# %%
# !pip install mysql-connector-python

# !pip install pandas

# !pip install SQLAlchemy
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\likit\anaconda3\lib\site-packages (26.7.0)
# Requirement already satisfied: pandas in c:\users\likit\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\likit\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\likit\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\likit\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\likit\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\likit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: SQLAlchemy in c:\users\likit\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\likit\anaconda3\lib\site-packages (from SQLAlchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\likit\anaconda3\lib\site-packages (from SQLAlchemy) (4.15.0)

# %%
import mysql.connector

import pandas as pd

# %%
conn=mysql.connector.connect(host='localhost', user='root', password='Likith@reddy612', database='likitha')

# %%
cursor = conn.cursor()

query = "SELECT * FROM EMP"

# %%
df = pd.read_sql(query, conn)

df
# Out:
# C:\Users\likit\AppData\Local\Temp\ipykernel_17532\2428951602.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN      20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1982-12-09  3000.0     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN      10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500.0     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1983-01-12  1100.0     NaN      20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03   950.0     NaN      30
# 12   7902    FORD    ANALYST  7566.0  1981-12-03  3000.0     NaN      20
# 13   7934  MILLER      CLERK  7782.0  1982-01-23  1300.0     NaN      10
